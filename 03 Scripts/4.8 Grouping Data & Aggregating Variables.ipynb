# %% [markdown]
# # Exercise 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ### This script contains:

# %% [markdown]
# ### 1. Grouping Data Examples

# %% [markdown]
# ### 2. Aggregating data with agg ( )

# %% [markdown]
# ### 3. Aggregating data with transform ( )

# %% [markdown]
# ### 4. Deriving columns with loc ( )

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 1. Grouping Data Examples

# %%
# Import orders_products_merged dataframe

path = r'/Users/queency_yustiawan/Study/CF/data analyst course/immersion/A4 exercise/Instacart Basket Analysis'

df_ords_prods_merge = pd.read_pickle (os.path.join (path, '02 Data', 'Prepared Data', 'orders_products_merge_derived.pkl'))

# %%
# Checking output

df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    order_interval_days  product_id  add_to_cart_order  reordered product_name  \
# 0                  NaN         196                  1          0         Soda
# 1                 15.0         196                  1          1         Soda
# 2                 21.0         196                  1          1         Soda
# 3                 29.0         196                  1          1         Soda
# 4                 28.0         196                  1          1         Soda
#
# ...

# %%
# Creating a subset of df_ords_prods_merge

df = df_ords_prods_merge [:1000000]

# %%
# Checking subset output

df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    order_interval_days  product_id  add_to_cart_order  reordered product_name  \
# 0                  NaN         196                  1          0         Soda
# 1                 15.0         196                  1          1         Soda
# 2                 21.0         196                  1          1         Soda
# 3                 29.0         196                  1          1         Soda
# 4                 28.0         196                  1          1         Soda
#
# ...

# %%
df.shape
# Out:
# (1000000, 18)

# %%
# Grouping data by 'product_name'

df.groupby ('product_name')

# %% [markdown]
# ### 2. Aggregating data with agg ( )

# %%
# Grouping data by 'department_id' and aggregate the 'order_number'

df.groupby ('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Aggregate without using agg ( ) function, but mean ( )

df.groupby ('department_id') ['order_number'].mean ()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Multiple Aggregations

df.groupby ('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ### 3. Aggregating data with transform ( )

# %%
# Creating 'max_order' column

df_ords_prods_merge ['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/8k/dxgtncgd49g2ryx410bsc12r0000gn/T/ipykernel_27544/2124903464.py:3: FutureWarning: The provided callable <function amax at 0x112ffec00> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge ['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    order_interval_days  product_id  add_to_cart_order  reordered product_name  \
# 0                  NaN         196                  1          0         Soda
# 1                 15.0         196                  1          1         Soda
# 2                 21.0         196                  1          1         Soda
# 3                 29.0         196                  1          1         Soda
# 4                 28.0         196                  1          1         Soda
#
# ...

# %% [markdown]
# ### 4. Deriving columns with loc ( )

# %%
# Create 'loyalty_flag' column

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal Customer'

df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular Customer'

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
# checking frequency loyalty flag

df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: count, dtype: int64

# %%
# Checking output

df_ords_prods_merge [['user_id', 'loyalty_flag', 'order_number', 'max_order']].head(60)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0         1      New Customer             1         10
# 1         1      New Customer             2         10
# 2         1      New Customer             3         10
# 3         1      New Customer             4         10
# 4         1      New Customer             5         10
# 5         1      New Customer             6         10
# 6         1      New Customer             7         10
# 7         1      New Customer             8         10
# 8         1      New Customer             9         10
# 9         1      New Customer            10         10
# 10       15  Regular Customer            15         22
# 11       15  Regular Customer            17         22
# 12       15  Regular Customer            18         22
# 13       15  Regular Customer            21         22
# 14       15  Regular Customer            22         22
# 15       19      New Customer             2          9
# ...
